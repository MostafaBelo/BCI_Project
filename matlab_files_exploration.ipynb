# %%
from hdf5storage import loadmat

# %%
mat = loadmat("/mnt/C/BCI Dataset/Task1_Matlab/Matlab files/resultsZAB_SR.mat")

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'sentenceData'])

# %%
mat["sentenceData"].dtype
# Out:
# dtype([('content', 'O'), ('rawData', 'O'), ('mean_t1', 'O'), ('mean_t2', 'O'), ('mean_a1', 'O'), ('mean_a2', 'O'), ('mean_b1', 'O'), ('mean_b2', 'O'), ('mean_g1', 'O'), ('mean_g2', 'O'), ('mean_t1_sec', 'O'), ('mean_t2_sec', 'O'), ('mean_a1_sec', 'O'), ('mean_a2_sec', 'O'), ('mean_b1_sec', 'O'), ('mean_b2_sec', 'O'), ('mean_g1_sec', 'O'), ('mean_g2_sec', 'O'), ('mean_t1_diff', 'O'), ('mean_t2_diff', 'O'), ('mean_a1_diff', 'O'), ('mean_a2_diff', 'O'), ('mean_b1_diff', 'O'), ('mean_b2_diff', 'O'), ('mean_g1_diff', 'O'), ('mean_g2_diff', 'O'), ('mean_t1_diff_sec', 'O'), ('mean_t2_diff_sec', 'O'), ('mean_a1_diff_sec', 'O'), ('mean_a2_diff_sec', 'O'), ('mean_b1_diff_sec', 'O'), ('mean_b2_diff_sec', 'O'), ('mean_g1_diff_sec', 'O'), ('mean_g2_diff_sec', 'O'), ('word', 'O'), ('omissionRate', 'O'), ('allFixations', 'O'), ('wordbounds', 'O'), ('answer_mean_t1', 'O'), ('answer_mean_t2', 'O'), ('answer_mean_a1', 'O'), ('answer_mean_a2', 'O'), ('answer_mean_b1', 'O'), ('answer_mean_b2', 'O'), ('answer_mean_g1', 'O'), ('answer_mean_g2', 'O'), ('answer_mean_t1_diff', 'O'), ('answer_mean_t2_diff', 'O'), ('answer_mean_a1_diff', 'O'), ('answer_mean_a2_diff', 'O'), ('answer_mean_b1_diff', 'O'), ('answer_mean_b2_diff', 'O'), ('answer_mean_g1_diff', 'O'), ('answer_mean_g2_diff', 'O')])

# %%
mat["sentenceData"]["content"][0,1]
# Out:
# array(['Beautifully crafted, engaging filmmaking that should attract upscale audiences hungry for quality and a nostalgic, twisty yarn that will keep them guessing.'],
#       dtype='<U156')

# %%
mat["sentenceData"]["rawData"][0,1]
# Out:
# array([[ 0.31344172,  0.69693404, -0.05696342, ...,  0.05824491,
#         -0.53018284, -0.537511  ],
#        [ 0.36348966, -0.04016582, -0.22898431, ..., -0.590284  ,
#         -0.5384082 , -0.70187634],
#        [ 0.89097756,  1.3332819 ,  0.37423965, ...,  0.7662453 ,
#         -0.3242263 , -1.0619977 ],
#        ...,
#        [-0.12457634,  1.5733595 ,  1.6647291 , ...,  0.36703458,
#         -0.35501048, -0.8102827 ],
#        [-0.12482326,  2.6448221 ,  2.412978  , ...,  1.765022  ,
#          0.05571292, -0.5650343 ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]], shape=(105, 3412), dtype=float32)

# %%
sentence_id = 1 # 0-399
word_id = 1 # 0-21
mat["sentenceData"]["word"][0,sentence_id][0,word_id].dtype
# Out:
# dtype([('content', 'O'), ('fixPositions', 'O'), ('nFixations', 'O'), ('meanPupilSize', 'O'), ('rawEEG', 'O'), ('rawET', 'O'), ('FFD', 'O'), ('FFD_pupilsize', 'O'), ('FFD_t1', 'O'), ('FFD_t2', 'O'), ('FFD_a1', 'O'), ('FFD_a2', 'O'), ('FFD_b1', 'O'), ('FFD_b2', 'O'), ('FFD_g1', 'O'), ('FFD_g2', 'O'), ('FFD_t1_diff', 'O'), ('FFD_t2_diff', 'O'), ('FFD_a1_diff', 'O'), ('FFD_a2_diff', 'O'), ('FFD_b1_diff', 'O'), ('FFD_b2_diff', 'O'), ('FFD_g1_diff', 'O'), ('FFD_g2_diff', 'O'), ('TRT', 'O'), ('TRT_pupilsize', 'O'), ('TRT_t1', 'O'), ('TRT_t2', 'O'), ('TRT_a1', 'O'), ('TRT_a2', 'O'), ('TRT_b1', 'O'), ('TRT_b2', 'O'), ('TRT_g1', 'O'), ('TRT_g2', 'O'), ('TRT_t1_diff', 'O'), ('TRT_t2_diff', 'O'), ('TRT_a1_diff', 'O'), ('TRT_a2_diff', 'O'), ('TRT_b1_diff', 'O'), ('TRT_b2_diff', 'O'), ('TRT_g1_diff', 'O'), ('TRT_g2_diff', 'O'), ('GD', 'O'), ('GD_pupilsize', 'O'), ('GD_t1', 'O'), ('GD_t2', 'O'), ('GD_a1', 'O'), ('GD_a2', 'O'), ('GD_b1', 'O'), ('GD_b2', 'O'), ('GD_g1', 'O'), ('GD_g2', 'O'), ('GD_t1_diff', 'O'), ('GD_t2_diff', 'O'), ('GD_a1_diff', 'O'), ('GD_a2_diff', 'O'), ('GD_b1_diff', 'O'), ('GD_b2_diff', 'O'), ('GD_g1_diff', 'O'), ('GD_g2_diff', 'O'), ('GPT', 'O'), ('GPT_pupilsize', 'O'), ('GPT_t1', 'O'), ('GPT_t2', 'O'), ('GPT_a1', 'O'), ('GPT_a2', 'O'), ('GPT_b1', 'O'), ('GPT_b2', 'O'), ('GPT_g1', 'O'), ('GPT_g2', 'O'), ('GPT_t1_diff', 'O'), ('GPT_t2_diff', 'O'), ('GPT_a1_diff', 'O'), ('GPT_a2_diff', 'O'), ('GPT_b1_diff', 'O'), ('GPT_b2_diff', 'O'), ('GPT_g1_diff', 'O'), ('GPT_g2_diff', 'O'), ('SFD', 'O'), ('SFD_pupilsize', 'O'), ('SFD_t1', 'O'), ('SFD_t2', 'O'), ('SFD_a1', 'O'), ('SFD_a2', 'O'), ('SFD_b1', 'O'), ('SFD_b2', 'O'), ('SFD_g1', 'O'), ('SFD_g2', 'O'), ('SFD_t1_diff', 'O'), ('SFD_t2_diff', 'O'), ('SFD_a1_diff', 'O'), ('SFD_a2_diff', 'O'), ('SFD_b1_diff', 'O'), ('SFD_b2_diff', 'O'), ('SFD_g1_diff', 'O'), ('SFD_g2_diff', 'O')])

# %%
mat["sentenceData"]["word"][0,1][0,0]["content"]
# Out:
# array(['Beautifully'], dtype='<U11')

# %%
mat["sentenceData"]["word"][0,1][0,10]["rawEEG"].shape
# Out:
# (1, 0)

# %%
mat["sentenceData"]["word"][0,1][0,10]["nFixations"]
# Out:
# array([], shape=(0, 0), dtype=uint8)

# %%
mat["sentenceData"]["word"][0,1]["fixPositions"][0]
# Out:
# array([array([[1, 2]], dtype=uint8), array([[3]], dtype=uint8),
#        array([[4, 5, 6]], dtype=uint8), array([[7]], dtype=uint8),
#        array([[8]], dtype=uint8), array([[9]], dtype=uint8),
#        array([[10]], dtype=uint8), array([[11, 13]], dtype=uint8),
#        array([[12, 14]], dtype=uint8), array([[15, 16]], dtype=uint8),
#        array([], shape=(0, 0), dtype=uint8), array([[17]], dtype=uint8),
#        array([], shape=(0, 0), dtype=uint8), array([[18]], dtype=uint8),
#        array([[19]], dtype=uint8), array([[20]], dtype=uint8),
#        array([[21]], dtype=uint8), array([], shape=(0, 0), dtype=uint8),
#        array([[22]], dtype=uint8), array([[23]], dtype=uint8),
#        array([[25]], dtype=uint8), array([[24, 26]], dtype=uint8)],
#       dtype=object)
